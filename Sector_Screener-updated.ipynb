# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/STOCKS/blob/code/Sector_Screener-updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

# Fetch S&P 500 list from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_table = pd.read_html(url, header=0)
sp500_df = sp500_table[0]

# Function to fetch and plot data for a given sector
def plot_sector_data(sector_name, df):
    sector_companies = df[df['GICS Sector'] == sector_name]

    # Initialize data structure
    data = {
        'Company': [],
        'Ticker': [],
        'PE Ratio': [],
        'YoY Revenue Growth': [],
        'ROE': [],
        'Gross Margin': [],
        'R&D Spending': [],
        "Price to Book Value":[],
        "Return on Assets": [],
        "Debt to Equity":[]
    }

    # Fetch financial data for each company in the sector
    for ticker in sector_companies['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info

        # Append company data
        data['Company'].append(info.get('longName', 'N/A'))
        data['Ticker'].append(ticker)
        data['PE Ratio'].append(info.get('forwardPE', 0))
        data['YoY Revenue Growth'].append(info.get('revenueGrowth', 0))
        data['ROE'].append(info.get('returnOnEquity', 0))
        data['Gross Margin'].append(info.get('grossMargins', 0))
        data['R&D Spending'].append(info.get('researchDevelopment', 0))
        data['Price to Book Value'].append(info.get('priceToBook', 0))
        data['Return on Assets'].append(info.get('returnOnAssets', 0))
        data['Debt to Equity'].append(info.get('debtToEquity', 0))

    # Convert to DataFrame
    df = pd.DataFrame(data)

    # Calculate averages
    averages = df.mean().to_dict()
    averages['Company'] = 'Average'
    averages['Ticker'] = ''
    df = df.append(averages, ignore_index=True)

    # Plot with Plotly
    fig = go.Figure(data=[go.Table(
        header=dict(values=list(df.columns), fill_color='paleturquoise', align='left'),
        cells=dict(values=[df[k].tolist() for k in df.columns], fill_color='lavender', align='left'))
    ])
    fig.show()

# Example: Plot for one sector, repeat for others as needed
plot_sector_data('Health Care', sp500_df)
# Out:
# <ipython-input-45-227c4babfed0>:49: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-45-227c4babfed0>:52: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_sector_data('Energy', sp500_df)
# Out:
# <ipython-input-45-227c4babfed0>:49: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-45-227c4babfed0>:52: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_sector_data('Information Technology', sp500_df)
# Out:
# <ipython-input-45-227c4babfed0>:49: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-45-227c4babfed0>:52: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_sector_data('Financials', sp500_df)
# Out:
# <ipython-input-45-227c4babfed0>:49: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-45-227c4babfed0>:52: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

# Fetch S&P 500 list from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
tables = pd.read_html(url)
sp500_df = tables[0]

# Initialize Plotly figures for each sector
sector_figures = {}

# Metrics including new ones
extended_metrics = ['forwardPE', 'revenueGrowth', 'returnOnEquity', 'grossMargins', 'researchDevelopment', 'priceToBook', 'returnOnAssets', 'debtToEquity']  # MACD will be handled separately

# Iterate through each sector
for sector in sp500_df['GICS Sector'].unique():
    sector_data = []
    sector_companies = sp500_df[sp500_df['GICS Sector'] == sector]

    for ticker in sector_companies['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info

        # Collecting additional metrics
        company_data = {
            'Company': info.get('longName'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE'),
            'YoY Revenue Growth': info.get('revenueGrowth'),
            'ROE': info.get('returnOnEquity'),
            'Gross Margin': info.get('grossMargins'),
            'R&D Spending': info.get('researchDevelopment'),
            'PBV': info.get('priceToBook'),
            'ROA': info.get('returnOnAssets'),
            'Debt to Equity': info.get('debtToEquity'),
            # MACD Bullish/Bearish status would require historical data and additional logic
            # For simplicity, this part is omitted from the example
        }
        sector_data.append(company_data)

    # Convert sector data to DataFrame
    df = pd.DataFrame(sector_data)

    # Calculate averages for each numeric column and append to the DataFrame
    averages = df.mean().to_dict()
    averages['Company'] = 'Average'
    averages['Ticker'] = ''
    df = df.append(averages, ignore_index=True)

    # Creating a Plotly table for the sector
    fig = go.Figure(data=[go.Table(
        header=dict(values=df.columns, fill_color='paleturquoise', align='left'),
        cells=dict(values=[df[col] for col in df.columns], fill_color='lavender', align='left'))
    ])

    # Store the figure in the dictionary
    sector_figures[sector] = fig

# Display the tables for each sector
for sector, fig in sector_figures.items():
    print(f"Displaying table for sector: {sector}")
    fig.show()
# Out:
# <ipython-input-49-7f62cfaf89fe>:46: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-49-7f62cfaf89fe>:49: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-49-7f62cfaf89fe>:46: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# <ipython-input-49-7f62cfaf89fe>:49: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# ...

# %%
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

# Fetch S&P 500 list from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_df = pd.read_html(url, header=0)[0]

# Filter for Information Technology companies
it_companies = sp500_df[sp500_df['GICS Sector'] == 'Information Technology']

# Group by GICS Sub-Industry
sub_industry_groups = it_companies.groupby('GICS Sub-Industry')

# Processing each Sub-Industry
for sub_industry, group in sub_industry_groups:
    print(f"Processing {sub_industry}...")
    sector_data = []

    for ticker in group['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info

        company_data = {
            'Company': info.get('longName'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE'),
            'YoY Revenue Growth': info.get('revenueGrowth'),
            'ROE': info.get('returnOnEquity'),
            'Gross Margin': info.get('grossMargins'),
            'R&D Spending': info.get('researchDevelopment'),
            'PBV': info.get('priceToBook'),
            'ROA': info.get('returnOnAssets'),
            'Debt to Equity': info.get('debtToEquity'),
            # Simplified MACD indicator; in practice, you would calculate this from historical data
            'MACD Indicator': 'Not Calculated'  # Placeholder for simplicity
        }
        sector_data.append(company_data)

    df = pd.DataFrame(sector_data)
    # Creating a Plotly table for the sub-industry
    fig = go.Figure(data=[go.Table(
        header=dict(values=df.columns, fill_color='paleturquoise', align='left'),
        cells=dict(values=[df[col] for col in df.columns], fill_color='lavender', align='left'))
    ])
    fig.update_layout(title=f"{sub_industry} Sub-Industry")
    fig.show()
# Out:
# Processing Application Software...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# For each sector in the S&P 500
for sector in sp500_df['GICS Sector'].unique():
    sector_companies = sp500_df[sp500_df['GICS Sector'] == sector]
    growth_data = []

    for ticker in sector_companies['Symbol']:
        try:
            stock = yf.Ticker(ticker)
            info = stock.info

            growth_data.append({
                'Company': info.get('longName'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE'),
            'YoY Revenue Growth': info.get('revenueGrowth'),
            'ROE': info.get('returnOnEquity'),
            'Gross Margin': info.get('grossMargins'),
            'PBV': info.get('priceToBook'),
            'ROA': info.get('returnOnAssets'),
            'Debt to Equity': info.get('debtToEquity'),
            'Dividend Yield': info.get('dividendYield', 0) * 100

            })
        except Exception as e:
            print(f"Could not process {ticker}: {e}")

    # Sort by YoY Revenue Growth and select top 5
    df = pd.DataFrame(growth_data).sort_values(by='YoY Revenue Growth', ascending=False).head(5)

    # Create and display a Plotly table for top 5 companies in this sector
    fig = go.Figure(data=[go.Table(
        header=dict(values=df.columns, fill_color='paleturquoise', align='left'),
        cells=dict(values=[df[col] for col in df.columns], fill_color='lavender', align='left'))
    ])
    fig.update_layout(title=f"Top 5 Companies by YoY Revenue Growth in {sector} Sector")
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Example for a single company (replace 'AAPL' with your dynamic ticker)
ticker = 'NVDA'
stock = yf.Ticker(ticker)
hist = stock.history(period="1y")

# Calculate SMAs
hist['SMA50'] = hist['Close'].rolling(window=50).mean()
hist['SMA200'] = hist['Close'].rolling(window=200).mean()

# Plotting
fig = go.Figure(data=[go.Candlestick(x=hist.index,
                open=hist['Open'], high=hist['High'],
                low=hist['Low'], close=hist['Close'],
                name='Candlestick'),
          go.Scatter(x=hist.index, y=hist['SMA50'], line=dict(color='blue', width=1), name='SMA50'),
          go.Scatter(x=hist.index, y=hist['SMA200'], line=dict(color='red', width=1), name='SMA200')])
fig.update_layout(title=f"{ticker} Candlestick Chart with SMA50 and SMA200", xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Example for a single company
ticker = 'NVDA'
stock = yf.Ticker(ticker)
holders = stock.institutional_holders  # This might vary based on the data available

print(holders.head())  # Display top holders; adapt as needed for your requirements
# Out:
#   Date Reported                         Holder  pctHeld     Shares  \
# 0    2023-06-30             Vanguard Group Inc   0.0815  201392728
# 1    2023-06-30                 Blackrock Inc.   0.0737  182096923
# 2    2023-06-30                       FMR, LLC   0.0532  131491181
# 3    2023-06-30       State Street Corporation   0.0370   91510810
# 4    2023-06-30  Price (T.Rowe) Associates Inc   0.0222   54723581
#
#          Value
# 0  85193151798
# 1  77030640367
# 2  55623399386
# 3  38710902846
# 4  23149169234
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py:557: RuntimeWarning:
#
# invalid value encountered in cast

# %%
import yfinance as yf
import plotly.graph_objects as go

# Define the stock ticker
ticker_symbol = 'NVDA'
stock = yf.Ticker(ticker_symbol)

# Fetch financial data
financials= stock.financials
balance_sheet = stock.balance_sheet
cash_flow = stock.cashflow

# Get historical stock price data
hist_data = stock.history(period="5y")

# %%
balance_sheet
# Out:
#                                                      2024-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             2464000000.0
# Share Issued                                       2464000000.0
# Net Debt                                           2429000000.0
# Total Debt                                        11056000000.0
# ...                                                         ...
# Allowance For Doubtful Accounts Receivable                  NaN
# Gross Accounts Receivable                                   NaN
# Cash Cash Equivalents And Short Term Investments  25984000000.0
# Other Short Term Investments                      18704000000.0
# Cash And Cash Equivalents                          7280000000.0
#
#                                                      2023-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             2466136572.0
# ...

# %%
fig_bs = go.Figure(data=[go.Table(
    header=dict(values=["Metric"] + [str(year.date()) for year in balance_sheet.columns],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[balance_sheet.index] + [balance_sheet[year] for year in balance_sheet.columns],
               fill=dict(color=['lavender', 'white']),
               align='left'))])

fig_bs.update_layout(title="Balance Sheet for the Past 5 Years")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_cf = go.Figure(data=[go.Table(
    header=dict(values=["Metric"] + [str(year.date()) for year in cash_flow.columns],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[cash_flow.index] + [cash_flow[year] for year in cash_flow.columns],
               fill=dict(color=['lavender', 'white']),
               align='left'))])

fig_cf.update_layout(title="Cash Flow Statement for the Past 5 Years")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plotting Revenue Growth
fig_revenue = go.Figure()
fig_revenue.add_trace(go.Bar(x=[str(year.date()) for year in financials.columns],
                             y=financials.loc['Total Revenue'],
                             name='Revenue'))
fig_revenue.update_layout(title_text="Revenue Growth Over the Past 5 Years",
                          xaxis_title="Year",
                          yaxis_title="Total Revenue")

# Plotting Stock Price
fig_stock_price = go.Figure()
fig_stock_price.add_trace(go.Scatter(x=hist_data.index,
                                     y=hist_data['Close'],

                                     mode='lines',
                                     name='Stock Price'))
fig_stock_price.update_layout(title_text="Stock Price Over the Past 5 Years",
                              xaxis_title="Date",
                              yaxis_title="Price")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
total_revenue = financials.loc['Total Revenue']
revenue_dates = [str(year.date()) for year in financials.columns]

# Extracting Close prices and dates for stock price plotting
close_prices = hist_data['Close']
price_dates = hist_data.index

# %%
# Plotting Revenue Growth
fig_revenue = go.Figure()
fig_revenue.add_trace(go.Bar(x=revenue_dates, y=total_revenue, name='Total Revenue'))
fig_revenue.update_layout(title_text="Revenue Growth Over the Past 5 Years",
                          xaxis_title="Year",
                          yaxis_title="Total Revenue",
                          xaxis=dict(type='category'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plotting Stock Price
fig_stock_price = go.Figure()
fig_stock_price.add_trace(go.Scatter(x=price_dates, y=close_prices, mode='lines', name='Stock Price'))
fig_stock_price.update_layout(title_text="Stock Price Over the Past 5 Years",
                              xaxis_title="Date",
                              yaxis_title="Price")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
financials1 = stock.financials
hist_data1 = stock.history(period="10y")
total_revenue = financials1.loc['Total Revenue']
revenue_dates = [str(year.date()) for year in financials1.columns]

# Extracting Close prices and dates for stock price plotting
close_prices = hist_data1['Close']
price_dates = hist_data1.index

# %%
# Plotting Revenue Growth
fig_revenue = go.Figure()
fig_revenue.add_trace(go.Bar(x=revenue_dates, y=total_revenue, name='Total Revenue'))
fig_revenue.update_layout(title_text="Revenue Growth Over the Past 10 Years",
                          xaxis_title="Year",
                          yaxis_title="Total Revenue",
                          xaxis=dict(type='category'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plotting Stock Price
fig_stock_price = go.Figure()
fig_stock_price.add_trace(go.Scatter(x=price_dates, y=close_prices, mode='lines', name='Stock Price'))
fig_stock_price.update_layout(title_text="Stock Price Over the Past 10 Years",
                              xaxis_title="Date",
                              yaxis_title="Price")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install ipywidgets

# %%
sp500_df
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

def create_sector_figures(sector_name, df):
    sector_companies = df[df['GICS Sector'] == sector_name]
    sector_data = []

    for ticker in sector_companies['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info
        sector_data.append({
            'Company': info.get('longName', 'N/A'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE', 0),
            'YoY Revenue Growth': info.get('revenueGrowth', 0),
            'ROE': info.get('returnOnEquity', 0),
            'Gross Margin': info.get('grossMargins', 0),
            'R&D Spending': info.get('researchDevelopment', 0),
            'PBV': info.get('priceToBook', 0),
            'ROA': info.get('returnOnAssets', 0),
            'Debt to Equity': info.get('debtToEquity', 0),
        })

    # Convert to DataFrame
    df = pd.DataFrame(sector_data)

    # Calculate averages, specify numeric_only=True
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    averages = {col: df[col].mean() for col in numeric_cols}
    averages['Company'] = 'Sector Average'
    averages['Ticker'] = 'N/A'

    # Use concat instead of append to avoid FutureWarning
    averages_df = pd.DataFrame([averages])
    df = pd.concat([df, averages_df], ignore_index=True)

    return df

# Widget for sector selection
sector_dropdown = widgets.Dropdown(
    options=sp500_df['GICS Sector'].unique().tolist(),
    value=sp500_df['GICS Sector'].unique()[0],
    description='Sector:',
)

# Button to trigger data fetching and display
plot_button = widgets.Button(description='Show Sector Data')

# Output area for displaying tables
output = widgets.Output()

def on_plot_button_clicked(b):
    with output:
        output.clear_output()
        df = create_sector_figures(sector_dropdown.value, sp500_df)
        display(HTML(df.to_html(index=False)))

plot_button.on_click(on_plot_button_clicked)

# Display the widgets
display(sector_dropdown, plot_button, output)
# Out:
# Dropdown(description='Sector:', options=('Industrials', 'Health Care', 'Information Technology', 'Utilities', …
# Button(description='Show Sector Data', style=ButtonStyle())
# Output()

# %%
sp500_df
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

def create_sector_figures(df, filters=None):
    # Convert to DataFrame
    df = pd.DataFrame(df)

    if filters:
        for key, value in filters.items():
            if key == 'Top 5 YOY Growth':
                df = df.sort_values(by='YoY Revenue Growth', ascending=False).head(5)
            elif key == 'PE<5':
                df = df[df['PE Ratio'] < 5]

    # Calculate averages, specify numeric_only=True for numeric columns
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    averages = {col: df[col].mean() for col in numeric_cols}
    averages['Company'] = 'Sector Average'
    averages['Ticker'] = 'N/A'

    # Use concat instead of append to avoid FutureWarning
    averages_df = pd.DataFrame([averages])
    df = pd.concat([df, averages_df], ignore_index=True)

    return df

def fetch_sector_data(sector_name, sp500_df):
    sector_companies = sp500_df[sp500_df['GICS Sector'] == sector_name]
    sector_data = []

    for ticker in sector_companies['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info
        sector_data.append({
            'Company': info.get('longName', 'N/A'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE', 0),
            'YoY Revenue Growth': info.get('revenueGrowth', 0),
            'ROE': info.get('returnOnEquity', 0),
            'GICS Sub Industry': sector_companies[sector_companies['Symbol'] == ticker]['GICS Sub-Industry'].iloc[0],
            # Add other financial metrics as needed
        })

    return sector_data

# Widget for sector selection
sector_dropdown = widgets.Dropdown(
    options=[''] + sp500_df['GICS Sector'].unique().tolist(),
    value='',
    description='Sector:',
)

subsector_dropdown = widgets.Dropdown(
    description='Subsector:',
)

# Button to trigger data fetching and display
plot_button = widgets.Button(description='Show Sector Data')
top_5_growth_button = widgets.Button(description='Top 5 YOY Growth', disabled=True)
pe_less_than_5_button = widgets.Button(description='PE < 5', disabled=True)

# Output area for displaying tables
output = widgets.Output()

def update_subsector_options(change):
    sector_name = change.new
    if sector_name:
        subsectors = sp500_df[sp500_df['GICS Sector'] == sector_name]['GICS Sub-Industry'].unique().tolist()
        subsector_dropdown.options = [''] + subsectors
        subsector_dropdown.value = ''
    else:
        subsector_dropdown.options = []
    top_5_growth_button.disabled = pe_less_than_5_button.disabled = True

sector_dropdown.observe(update_subsector_options, names='value')

def on_plot_button_clicked(b):
    with output:
        output.clear_output()
        sector_name = sector_dropdown.value
        subsector_name = subsector_dropdown.value
        sector_data = fetch_sector_data(sector_name, sp500_df)

        if subsector_name:
            sector_data = [data for data in sector_data if data['GICS Sub-Industry'] == subsector_name]

        df = create_sector_figures(sector_data)
        display(HTML(df.to_html(index=False)))
        top_5_growth_button.disabled = pe_less_than_5_button.disabled = False

plot_button.on_click(on_plot_button_clicked)

def on_top_5_growth_button_clicked(b):
    with output:
        output.clear_output()
        sector_data = fetch_sector_data(sector_dropdown.value, sp500_df)
        df = create_sector_figures(sector_data, filters={'Top 5 YOY Growth': True})
        display(HTML(df.to_html(index=False)))

def on_pe_less_than_5_button_clicked(b):
    with output:
        output.clear_output()
        sector_data = fetch_sector_data(sector_dropdown.value, sp500_df)
        df = create_sector_figures(sector_data, filters={'PE<5': True})
        display(HTML(df.to_html(index=False)))

top_5_growth_button.on_click(on_top_5_growth_button_clicked)
pe_less_than_5_button.on_click(on_pe_less_than_5_button_clicked)

# Display the widgets
display(sector_dropdown, subsector_dropdown, plot_button, top_5_growth_button, pe_less_than_5_button, output)
# Out:
# Dropdown(description='Sector:', options=('', 'Industrials', 'Health Care', 'Information Technology', 'Utilitie…
# Dropdown(description='Subsector:', options=(), value=None)
# Button(description='Show Sector Data', style=ButtonStyle())
# Button(description='Top 5 YOY Growth', disabled=True, style=ButtonStyle())
# Button(description='PE < 5', disabled=True, style=ButtonStyle())
# Output()

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

def create_sector_figures(sector_name, df, filter_type=None):
    sector_companies = df[df['GICS Sector'] == sector_name]
    sector_data = []

    for ticker in sector_companies['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info
        sector_data.append({
            'Company': info.get('longName', 'N/A'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE', 0),
            'YoY Revenue Growth': info.get('revenueGrowth', 0),
            'ROE': info.get('returnOnEquity', 0),
            'Gross Margin': info.get('grossMargins', 0),
            'R&D Spending': info.get('researchDevelopment', 0),
            'PBV': info.get('priceToBook', 0),
            'ROA': info.get('returnOnAssets', 0),
            'Debt to Equity': info.get('debtToEquity', 0),
        })

    df = pd.DataFrame(sector_data)

    if filter_type == 'Top 5 YoY Growth':
        df = df.sort_values(by='YoY Revenue Growth', ascending=False).head(5)
    elif filter_type == 'PE < 5':
        df = df[df['PE Ratio'] > 0]  # Filter out non-positive PE ratios
        df = df.sort_values(by='PE Ratio', ascending=True)
        df = df[df['PE Ratio'] < 5]

    # Calculate averages for filtered data if needed
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    averages = {col: df[col].mean() for col in numeric_cols}
    averages['Company'] = 'Sector Average' if not filter_type else ''
    averages['Ticker'] = 'N/A' if not filter_type else ''

    averages_df = pd.DataFrame([averages])
    df = pd.concat([df, averages_df], ignore_index=True)

    return df

sector_dropdown = widgets.Dropdown(
    options=sp500_df['GICS Sector'].unique().tolist(),
    value=sp500_df['GICS Sector'].unique()[0],
    description='Sector:',
)

plot_button = widgets.Button(description='Show Sector Data')
top_5_growth_button = widgets.Button(description='Top 5 YoY Growth')
pe_less_than_5_button = widgets.Button(description='PE < 5')

output = widgets.Output()

def on_plot_button_clicked(b):
    with output:
        output.clear_output()
        df = create_sector_figures(sector_dropdown.value, sp500_df)
        display(HTML(df.to_html(index=False)))

def on_top_5_growth_button_clicked(b):
    with output:
        output.clear_output()
        df = create_sector_figures(sector_dropdown.value, sp500_df, filter_type='Top 5 YoY Growth')
        display(HTML(df.to_html(index=False)))

def on_pe_less_than_5_button_clicked(b):
    with output:
        output.clear_output()
        df = create_sector_figures(sector_dropdown.value, sp500_df, filter_type='PE < 5')
        display(HTML(df.to_html(index=False)))

plot_button.on_click(on_plot_button_clicked)
top_5_growth_button.on_click(on_top_5_growth_button_clicked)
pe_less_than_5_button.on_click(on_pe_less_than_5_button_clicked)

display(sector_dropdown, plot_button, top_5_growth_button, pe_less_than_5_button, output)
# Out:
# Dropdown(description='Sector:', options=('Industrials', 'Health Care', 'Information Technology', 'Utilities', …
# Button(description='Show Sector Data', style=ButtonStyle())
# Button(description='Top 5 YoY Growth', style=ButtonStyle())
# Button(description='PE < 5', style=ButtonStyle())
# Output()

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

# Global variables to store current filters
current_sector = None
current_subsector = None
current_filters = {'Top 5 YoY Growth': False, 'PE < 5': False}

def fetch_and_filter_data():
    global current_sector, current_subsector, current_filters

    # Filter by sector
    filtered_df = sp500_df[sp500_df['GICS Sector'] == current_sector]

    # Further filter by sub-sector if specified
    if current_subsector and current_subsector != 'All':
        filtered_df = filtered_df[filtered_df['GICS Sub-Industry'] == current_subsector]

    sector_data = []

    for ticker in filtered_df['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info
        sector_data.append({
            'Company': info.get('longName', 'N/A'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE', 0),
            'YoY Revenue Growth': info.get('revenueGrowth', 0),
            'ROE': info.get('returnOnEquity', 0),
            'Gross Margin': info.get('grossMargins', 0),
            'R&D Spending': info.get('researchDevelopment', 0),
            'PBV': info.get('priceToBook', 0),
            'ROA': info.get('returnOnAssets', 0),
            'Debt to Equity': info.get('debtToEquity', 0),
        })

    df = pd.DataFrame(sector_data)

    # Apply additional filters
    if current_filters['Top 5 YoY Growth']:
        df = df.sort_values(by='YoY Revenue Growth', ascending=False).head(5)
    if current_filters['PE < 5']:
        df = df[df['PE Ratio'] > 0]  # Ensure PE Ratio is positive
        df = df[df['PE Ratio'] < 5]

    return df

# Widget setup
sector_dropdown = widgets.Dropdown(
    options=['All'] + sp500_df['GICS Sector'].unique().tolist(),
    value='All',
    description='Sector:',
)

subsector_dropdown = widgets.Dropdown(
    options=['All'],
    value='All',
    description='Sub-Sector:',
)

top_5_growth_button = widgets.Button(description='Top 5 YoY Growth')
pe_less_than_5_button = widgets.Button(description='PE < 5')
clear_filters_button = widgets.Button(description='Clear Filters')

output = widgets.Output()

# Button event handlers
def on_sector_change(change):
    global current_sector
    current_sector = change.new
    update_subsector_options()

def update_subsector_options():
    if current_sector and current_sector != 'All':
        subsectors = ['All'] + sp500_df[sp500_df['GICS Sector'] == current_sector]['GICS Sub-Industry'].unique().tolist()
    else:
        subsectors = ['All']
    subsector_dropdown.options = subsectors
    subsector_dropdown.value = 'All'

def on_subsector_change(change):
    global current_subsector
    current_subsector = change.new
    display_data()

def on_top_5_growth_button_clicked(b):
    global current_filters
    current_filters['Top 5 YoY Growth'] = not current_filters['Top 5 YoY Growth']
    display_data()

def on_pe_less_than_5_button_clicked(b):
    global current_filters
    current_filters['PE < 5'] = not current_filters['PE < 5']
    display_data()

def on_clear_filters_button_clicked(b):
    global current_filters
    current_filters = {'Top 5 YoY Growth': False, 'PE < 5': False}
    display_data()

def display_data():
    with output:
        output.clear_output()
        df = fetch_and_filter_data()
        display(HTML(df.to_html(index=False)))

# Hook up event listeners
sector_dropdown.observe(on_sector_change, names='value')
subsector_dropdown.observe(on_subsector_change, names='value')
top_5_growth_button.on_click(on_top_5_growth_button_clicked)
pe_less_than_5_button.on_click(on_pe_less_than_5_button_clicked)
clear_filters_button.on_click(on_clear_filters_button_clicked)

# Initialize
current_sector = sector_dropdown.value
update_subsector_options()
current_subsector = subsector_dropdown.value

# Display UI components
display(widgets.HBox([sector_dropdown, subsector_dropdown]))
display(widgets.HBox([top_5_growth_button, pe_less_than_5_button, clear_filters_button]))
display(output)
# Out:
# ...
# Output()

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

# Global variables to store current selections
current_sector = 'All'
current_subsector = 'All'
current_filters = {'Top 5 YoY Growth': False, 'PE < 5': False}

def fetch_and_filter_data():
    global current_sector, current_subsector, current_filters

    if current_sector == 'All':
        filtered_df = sp500_df.copy()
    else:
        filtered_df = sp500_df[sp500_df['GICS Sector'] == current_sector]
        if current_subsector != 'All':
            filtered_df = filtered_df[filtered_df['GICS Sub-Industry'] == current_subsector]

    sector_data = []
    for ticker in filtered_df['Symbol']:
        stock = yf.Ticker(ticker)
        info = stock.info
        sector_data.append({
            'Company': info.get('longName', 'N/A'),
            'Ticker': ticker,
            'PE Ratio': info.get('forwardPE', 0),
            'YoY Revenue Growth': info.get('revenueGrowth', 0),
            # Add more attributes as needed
        })

    df = pd.DataFrame(sector_data)

    if current_filters['Top 5 YoY Growth']:
        df = df.nlargest(5, 'YoY Revenue Growth')
    if current_filters['PE < 5']:
        df = df[(df['PE Ratio'] > 0) & (df['PE Ratio'] < 5)]

    return df

# Widget setup
sector_dropdown = widgets.Dropdown(
    options=['All'] + sorted(sp500_df['GICS Sector'].unique().tolist()),
    description='Sector:',
)

subsector_dropdown = widgets.Dropdown(
    description='Sub-Sector:',
    options=['All'],
    value='All'
)

top_5_growth_button = widgets.Button(description='Top 5 YoY Growth')
pe_less_than_5_button = widgets.Button(description='PE < 5')
clear_filters_button = widgets.Button(description='Clear Filters')
show_all_button = widgets.Button(description='Show All Data')

output = widgets.Output()

def update_subsector_options(*args):
    global current_subsector
    if current_sector == 'All':
        subsector_dropdown.options = ['All']
    else:
        subsectors = ['All'] + sorted(sp500_df[sp500_df['GICS Sector'] == current_sector]['GICS Sub-Industry'].unique().tolist())
        subsector_dropdown.options = subsectors
    current_subsector = 'All'
    subsector_dropdown.value = 'All'

sector_dropdown.observe(lambda change: update_sector(change.new), names='value')
subsector_dropdown.observe(lambda change: update_subsector(change.new), names='value')

def update_sector(new_sector):
    global current_sector
    current_sector = new_sector
    update_subsector_options()

def update_subsector(new_subsector):
    global current_subsector
    current_subsector = new_subsector
    display_data()

def on_button_clicked(b):
    global current_filters
    if b.description == 'Top 5 YoY Growth':
        current_filters['Top 5 YoY Growth'] = not current_filters['Top 5 YoY Growth']
    elif b.description == 'PE < 5':
        current_filters['PE < 5'] = not current_filters['PE < 5']
    elif b.description == 'Clear Filters':
        current_filters = {'Top 5 YoY Growth': False, 'PE < 5': False}
    display_data()

def display_data():
    with output:
        output.clear_output()
        df = fetch_and_filter_data()
        display(HTML(df.to_html(index=False)))

for button in [top_5_growth_button, pe_less_than_5_button, clear_filters_button, show_all_button]:
    button.on_click(on_button_clicked)

# Display UI components
display(widgets.HBox([sector_dropdown, subsector_dropdown]))
display(widgets.HBox([top_5_growth_button, pe_less_than_5_button, clear_filters_button, show_all_button]))
display(output)

# Initially display all data
display_data()
# Out:
# ...
# Output()

# %% [markdown]
# sentiment analysis
# top institutional investors
# enterprise value
# TAM (Total Adressable market of the sector)
# Performance %

# %%
import pandas as pd
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming sp500_df is your DataFrame containing S&P 500 companies info

# Mock function to simulate fetching news articles
def fetch_news_for_company(ticker):
    # In a real application, replace this with actual news fetching logic
    return [
        {"title": f"News headline 1 for {ticker}", "url": "https://example.com"},
        {"title": f"News headline 2 for {ticker}", "url": "https://example.com"},
        {"title": f"News headline 3 for {ticker}", "url": "https://example.com"},
        {"title": f"News headline 4 for {ticker}", "url": "https://example.com"},
        {"title": f"News headline 5 for {ticker}", "url": "https://example.com"},
    ]

def display_news_for_top_companies(sector):
    df = fetch_and_filter_data()  # Reuse existing function to get filtered data
    top_companies = df.nlargest(5, 'YoY Revenue Growth')['Ticker'].tolist()

    news_output.clear_output()
    with news_output:
        for ticker in top_companies:
            news_articles = fetch_news_for_company(ticker)
            display(HTML(f'<h3>News for {ticker}</h3>'))
            for article in news_articles:
                display(HTML(f'<a href="{article["url"]}">{article["title"]}</a><br>'))

# Add a button to fetch news for the top 5 companies
fetch_news_button = widgets.Button(description='Fetch News for Top 5 Companies')

# Output area for news
news_output = widgets.Output()

fetch_news_button.on_click(lambda b: display_news_for_top_companies(current_sector))

# Display UI components
display(widgets.HBox([sector_dropdown, subsector_dropdown]))
display(widgets.HBox([top_5_growth_button, pe_less_than_5_button, clear_filters_button, show_all_button, fetch_news_button]))
display(output)
display(news_output)

# Initially display all data
display_data()
# Out:
# ...
# Output()
# Output()

# %%
import yfinance as yf

def fetch_news_for_company(ticker):
    stock = yf.Ticker(ticker)
    news_items = stock.news
    # Limit to top 5 news articles
    top_news = news_items[:5]
    return top_news

# %%
import yfinance as yf
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming the rest of the setup remains the same

# Modified function to fetch and display news
def display_news_for_top_companies(sector):
    df = fetch_and_filter_data()  # Assuming this function gives you the top companies based on your criteria
    top_companies = df.nlargest(5, 'YoY Revenue Growth')['Ticker'].tolist()

    news_output.clear_output()
    with news_output:
        for ticker in top_companies:
            news_articles = fetch_news_for_company(ticker)
            display(HTML(f'<h3>News for {ticker}</h3>'))
            for article in news_articles:
                display(HTML(f'<a href="{article["link"]}">{article["title"]}</a><br>'))

# Use the existing setup for the GUI elements and event handlers

# Make sure to call the display_news_for_top_companies function when the Fetch News button is clicked
fetch_news_button.on_click(lambda b: display_news_for_top_companies(current_sector))

# Remember to display the fetch_news_button along with other GUI components if not already done
display(fetch_news_button)
display(news_output)
# Out:
# Button(description='Fetch News for Top 5 Companies', style=ButtonStyle())
# Output()
